# %%
import pandas as pd 
import numpy as np

# %%
pd.read_csv("data/adult.data")
# Out:
#        39          State-gov   77516    Bachelors   13        Never-married  \
# 0      50   Self-emp-not-inc   83311    Bachelors   13   Married-civ-spouse
# 1      38            Private  215646      HS-grad    9             Divorced
# 2      53            Private  234721         11th    7   Married-civ-spouse
# 3      28            Private  338409    Bachelors   13   Married-civ-spouse
# 4      37            Private  284582      Masters   14   Married-civ-spouse
# ...    ..                ...     ...          ...  ...                  ...
# 32555  27            Private  257302   Assoc-acdm   12   Married-civ-spouse
# 32556  40            Private  154374      HS-grad    9   Married-civ-spouse
# 32557  58            Private  151910      HS-grad    9              Widowed
# 32558  22            Private  201490      HS-grad    9        Never-married
# 32559  52       Self-emp-inc  287927      HS-grad    9   Married-civ-spouse
#
# ...

# %%
pd.read_csv("data/adult.test")
# Out:
#                                                                                                                                                      |1x3 Cross validator
# 25  Private      226802  11th         7   Never-married       Machine-op-inspct  Own-child       Black               Male   0    0 40  United-States               <=50K.
# 38  Private      89814   HS-grad      9   Married-civ-spouse  Farming-fishing    Husband         White               Male   0    0 50  United-States               <=50K.
# 28  Local-gov    336951  Assoc-acdm   12  Married-civ-spouse  Protective-serv    Husband         White               Male   0    0 40  United-States                >50K.
# 44  Private      160323  Some-college 10  Married-civ-spouse  Machine-op-inspct  Husband         Black               Male   7688 0 40  United-States                >50K.
# ...

# %%
column_names = [
    'age', 'workclass', 'fnlwgt', 'education', 'education-num',
    'marital-status', 'occupation', 'relationship', 'race', 'sex',
    'capital-gain', 'capital-loss', 'hours-per-week', 'native-country', 'class'
]

# %%
# Read CSV files with column names
df_train = pd.read_csv('data/adult.data', names=column_names)
df_test = pd.read_csv('data/adult.test', names=column_names)

# Concatenate dataframes
df_combined = pd.concat([df_train, df_test], ignore_index=True)

# %%
df_combined
# Out:
#       age          workclass    fnlwgt   education  education-num  \
# 0      39          State-gov   77516.0   Bachelors           13.0
# 1      50   Self-emp-not-inc   83311.0   Bachelors           13.0
# 2      38            Private  215646.0     HS-grad            9.0
# 3      53            Private  234721.0        11th            7.0
# 4      28            Private  338409.0   Bachelors           13.0
# ...    ..                ...       ...         ...            ...
# 48838  39            Private  215419.0   Bachelors           13.0
# 48839  64                  ?  321403.0     HS-grad            9.0
# 48840  38            Private  374983.0   Bachelors           13.0
# 48841  44            Private   83891.0   Bachelors           13.0
# 48842  35       Self-emp-inc  182148.0   Bachelors           13.0
#
#             marital-status          occupation     relationship  \
# 0            Never-married        Adm-clerical    Not-in-family
# ...

# %%
df_combined.to_csv("data/censusincome",index=False)

# %%
data = pd.read_csv("data/censusincome")

# %%
data.head()
# Out:
#   age          workclass    fnlwgt   education  education-num  \
# 0  39          State-gov   77516.0   Bachelors           13.0
# 1  50   Self-emp-not-inc   83311.0   Bachelors           13.0
# 2  38            Private  215646.0     HS-grad            9.0
# 3  53            Private  234721.0        11th            7.0
# 4  28            Private  338409.0   Bachelors           13.0
#
#         marital-status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital-gain  capital-loss  hours-per-week  native-country   class
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48843 entries, 0 to 48842
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             48843 non-null  object
#  1   workclass       48842 non-null  object
#  2   fnlwgt          48842 non-null  float64
#  3   education       48842 non-null  object
#  4   education-num   48842 non-null  float64
#  5   marital-status  48842 non-null  object
#  6   occupation      48842 non-null  object
#  7   relationship    48842 non-null  object
#  8   race            48842 non-null  object
#  9   sex             48842 non-null  object
#  10  capital-gain    48842 non-null  float64
#  11  capital-loss    48842 non-null  float64
#  12  hours-per-week  48842 non-null  float64
#  13  native-country  48842 non-null  object
#  14  class           48842 non-null  object
# dtypes: float64(5), object(10)
# memory usage: 5.6+ MB

# %%
data_copy = data

# %%
data_copy.duplicated().value_counts()
# Out:
# False    48814
# True        29
# dtype: int64

# %%
len(data_copy[data_copy.duplicated()])
# Out:
# 29

# %%
data_copy[data_copy.duplicated()]
# Out:
#       age          workclass    fnlwgt      education  education-num  \
# 4881   25            Private  308144.0      Bachelors           13.0
# 5104   90            Private   52386.0   Some-college           10.0
# 9171   21            Private  250051.0   Some-college           10.0
# 11631  20            Private  107658.0   Some-college           10.0
# 13084  25            Private  195994.0        1st-4th            2.0
# 15059  21            Private  243368.0      Preschool            1.0
# 17040  46            Private  173243.0        HS-grad            9.0
# 18555  30            Private  144593.0        HS-grad            9.0
# 18698  19            Private   97261.0        HS-grad            9.0
# 21318  19            Private  138153.0   Some-college           10.0
# 21490  19            Private  146679.0   Some-college           10.0
# 21875  49            Private   31267.0        7th-8th            4.0
# 22300  25            Private  195994.0        1st-4th            2.0
# ...

# %%
data_copy.drop_duplicates(inplace=True)

# %%
data_copy
# Out:
#       age          workclass    fnlwgt   education  education-num  \
# 0      39          State-gov   77516.0   Bachelors           13.0
# 1      50   Self-emp-not-inc   83311.0   Bachelors           13.0
# 2      38            Private  215646.0     HS-grad            9.0
# 3      53            Private  234721.0        11th            7.0
# 4      28            Private  338409.0   Bachelors           13.0
# ...    ..                ...       ...         ...            ...
# 48838  39            Private  215419.0   Bachelors           13.0
# 48839  64                  ?  321403.0     HS-grad            9.0
# 48840  38            Private  374983.0   Bachelors           13.0
# 48841  44            Private   83891.0   Bachelors           13.0
# 48842  35       Self-emp-inc  182148.0   Bachelors           13.0
#
#             marital-status          occupation     relationship  \
# 0            Never-married        Adm-clerical    Not-in-family
# ...

# %%
data_copy[data_copy.duplicated()]
# Out:
# Empty DataFrame
# Columns: [age, workclass, fnlwgt, education, education-num, marital-status, occupation, relationship, race, sex, capital-gain, capital-loss, hours-per-week, native-country, class]
# Index: []

# %%
data_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 48814 entries, 0 to 48842
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             48814 non-null  object
#  1   workclass       48813 non-null  object
#  2   fnlwgt          48813 non-null  float64
#  3   education       48813 non-null  object
#  4   education-num   48813 non-null  float64
#  5   marital-status  48813 non-null  object
#  6   occupation      48813 non-null  object
#  7   relationship    48813 non-null  object
#  8   race            48813 non-null  object
#  9   sex             48813 non-null  object
#  10  capital-gain    48813 non-null  float64
#  11  capital-loss    48813 non-null  float64
#  12  hours-per-week  48813 non-null  float64
#  13  native-country  48813 non-null  object
#  14  class           48813 non-null  object
# dtypes: float64(5), object(10)
# memory usage: 6.0+ MB

# %%
data_copy.isnull().sum()
# Out:
# age               0
# workclass         1
# fnlwgt            1
# education         1
# education-num     1
# marital-status    1
# occupation        1
# relationship      1
# race              1
# sex               1
# capital-gain      1
# capital-loss      1
# hours-per-week    1
# native-country    1
# class             1
# dtype: int64

# %%
data_copy.dropna(inplace=True)

# %%
data_copy.isnull().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education-num     0
# marital-status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital-gain      0
# capital-loss      0
# hours-per-week    0
# native-country    0
# class             0
# dtype: int64

# %%
data_copy['age']=data_copy['age'].astype('int')

# %%
data_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 48813 entries, 0 to 48842
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             48813 non-null  int32
#  1   workclass       48813 non-null  object
#  2   fnlwgt          48813 non-null  float64
#  3   education       48813 non-null  object
#  4   education-num   48813 non-null  float64
#  5   marital-status  48813 non-null  object
#  6   occupation      48813 non-null  object
#  7   relationship    48813 non-null  object
#  8   race            48813 non-null  object
#  9   sex             48813 non-null  object
#  10  capital-gain    48813 non-null  float64
#  11  capital-loss    48813 non-null  float64
#  12  hours-per-week  48813 non-null  float64
#  13  native-country  48813 non-null  object
#  14  class           48813 non-null  object
# dtypes: float64(5), int32(1), object(9)
# memory usage: 5.8+ MB

# %%
data_copy['workclass'].dtype
# Out:
# dtype('O')

# %%
data_copy['workclass'].unique()
# Out:
# array([' State-gov', ' Self-emp-not-inc', ' Private', ' Federal-gov',
#        ' Local-gov', ' ?', ' Self-emp-inc', ' Without-pay',
#        ' Never-worked'], dtype=object)

# %%
data_copy['workclass'].value_counts()
# Out:
#  Private             33879
#  Self-emp-not-inc     3861
#  Local-gov            3136
#  ?                    2799
#  State-gov            1981
#  Self-emp-inc         1694
#  Federal-gov          1432
#  Without-pay            21
#  Never-worked           10
# Name: workclass, dtype: int64

# %%
data_copy['workclass'] = data_copy['workclass'].str.replace('?','Private')
# Out:
# C:\Users\adity\AppData\Local\Temp\ipykernel_2856\3154904273.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   data_copy['workclass'] = data_copy['workclass'].str.replace('?','Private')

# %%
data_copy['workclass'].unique()
# Out:
# array([' State-gov', ' Self-emp-not-inc', ' Private', ' Federal-gov',
#        ' Local-gov', ' Self-emp-inc', ' Without-pay', ' Never-worked'],
#       dtype=object)

# %%
data_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 48813 entries, 0 to 48842
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             48813 non-null  int32
#  1   workclass       48813 non-null  object
#  2   fnlwgt          48813 non-null  float64
#  3   education       48813 non-null  object
#  4   education-num   48813 non-null  float64
#  5   marital-status  48813 non-null  object
#  6   occupation      48813 non-null  object
#  7   relationship    48813 non-null  object
#  8   race            48813 non-null  object
#  9   sex             48813 non-null  object
#  10  capital-gain    48813 non-null  float64
#  11  capital-loss    48813 non-null  float64
#  12  hours-per-week  48813 non-null  float64
#  13  native-country  48813 non-null  object
#  14  class           48813 non-null  object
# dtypes: float64(5), int32(1), object(9)
# memory usage: 5.8+ MB

# %%
data_copy['fnlwgt'].unique()
# Out:
# array([ 77516.,  83311., 215646., ..., 173449.,  89686., 350977.])

# %%
len(data_copy['fnlwgt'].unique())
# Out:
# 28523

# %%
data_copy['education'].unique()
# Out:
# array([' Bachelors', ' HS-grad', ' 11th', ' Masters', ' 9th',
#        ' Some-college', ' Assoc-acdm', ' Assoc-voc', ' 7th-8th',
#        ' Doctorate', ' Prof-school', ' 5th-6th', ' 10th', ' 1st-4th',
#        ' Preschool', ' 12th'], dtype=object)

# %%
data_copy['education'].value_counts()
# Out:
#  HS-grad         15777
#  Some-college    10869
#  Bachelors        8020
#  Masters          2656
#  Assoc-voc        2060
#  11th             1812
#  Assoc-acdm       1601
#  10th             1389
#  7th-8th           954
#  Prof-school       834
#  9th               756
#  12th              656
#  Doctorate         594
#  5th-6th           508
#  1st-4th           245
#  Preschool          82
# Name: education, dtype: int64

# %%
data_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 48813 entries, 0 to 48842
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             48813 non-null  int32
#  1   workclass       48813 non-null  object
#  2   fnlwgt          48813 non-null  float64
#  3   education       48813 non-null  object
#  4   education-num   48813 non-null  float64
#  5   marital-status  48813 non-null  object
#  6   occupation      48813 non-null  object
#  7   relationship    48813 non-null  object
#  8   race            48813 non-null  object
#  9   sex             48813 non-null  object
#  10  capital-gain    48813 non-null  float64
#  11  capital-loss    48813 non-null  float64
#  12  hours-per-week  48813 non-null  float64
#  13  native-country  48813 non-null  object
#  14  class           48813 non-null  object
# dtypes: float64(5), int32(1), object(9)
# memory usage: 5.8+ MB

# %%
data_copy['education-num'].unique()
# Out:
# array([13.,  9.,  7., 14.,  5., 10., 12., 11.,  4., 16., 15.,  3.,  6.,
#         2.,  1.,  8.])

# %%
data_copy['education-num'].value_counts()
# Out:
# 9.0     15777
# 10.0    10869
# 13.0     8020
# 14.0     2656
# 11.0     2060
# 7.0      1812
# 12.0     1601
# 6.0      1389
# 4.0       954
# 15.0      834
# 5.0       756
# 8.0       656
# 16.0      594
# 3.0       508
# 2.0       245
# 1.0        82
# Name: education-num, dtype: int64

# %%
data_copy['marital-status'].unique()
# Out:
# array([' Never-married', ' Married-civ-spouse', ' Divorced',
#        ' Married-spouse-absent', ' Separated', ' Married-AF-spouse',
#        ' Widowed'], dtype=object)

# %%
data_copy['marital-status'].value_counts()
# Out:
#  Married-civ-spouse       22372
#  Never-married            16098
#  Divorced                  6630
#  Separated                 1530
#  Widowed                   1518
#  Married-spouse-absent      628
#  Married-AF-spouse           37
# Name: marital-status, dtype: int64

# %%
data_copy['occupation'].unique()
# Out:
# array([' Adm-clerical', ' Exec-managerial', ' Handlers-cleaners',
#        ' Prof-specialty', ' Other-service', ' Sales', ' Craft-repair',
#        ' Transport-moving', ' Farming-fishing', ' Machine-op-inspct',
#        ' Tech-support', ' ?', ' Protective-serv', ' Armed-Forces',
#        ' Priv-house-serv'], dtype=object)

# %%
data_copy['occupation'].value_counts()
# Out:
#  Prof-specialty       6167
#  Craft-repair         6107
#  Exec-managerial      6084
#  Adm-clerical         5608
#  Sales                5504
#  Other-service        4919
#  Machine-op-inspct    3019
#  ?                    2809
#  Transport-moving     2355
#  Handlers-cleaners    2071
#  Farming-fishing      1487
#  Tech-support         1445
#  Protective-serv       983
#  Priv-house-serv       240
#  Armed-Forces           15
# Name: occupation, dtype: int64

# %%
data_copy['occupation'] = data_copy['occupation'].str.replace('?','Prof-specialty')
# Out:
# C:\Users\adity\AppData\Local\Temp\ipykernel_2856\1299887833.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   data_copy['occupation'] = data_copy['occupation'].str.replace('?','Prof-specialty')

# %%
data_copy['occupation'].unique()
# Out:
# array([' Adm-clerical', ' Exec-managerial', ' Handlers-cleaners',
#        ' Prof-specialty', ' Other-service', ' Sales', ' Craft-repair',
#        ' Transport-moving', ' Farming-fishing', ' Machine-op-inspct',
#        ' Tech-support', ' Protective-serv', ' Armed-Forces',
#        ' Priv-house-serv'], dtype=object)

# %%
data_copy['occupation'].value_counts()
# Out:
#  Prof-specialty       8976
#  Craft-repair         6107
#  Exec-managerial      6084
#  Adm-clerical         5608
#  Sales                5504
#  Other-service        4919
#  Machine-op-inspct    3019
#  Transport-moving     2355
#  Handlers-cleaners    2071
#  Farming-fishing      1487
#  Tech-support         1445
#  Protective-serv       983
#  Priv-house-serv       240
#  Armed-Forces           15
# Name: occupation, dtype: int64

# %%
data_copy['relationship'].unique()
# Out:
# array([' Not-in-family', ' Husband', ' Wife', ' Own-child', ' Unmarried',
#        ' Other-relative'], dtype=object)

# %%
data_copy['relationship'].value_counts()
# Out:
#  Husband           19709
#  Not-in-family     12567
#  Own-child          7576
#  Unmarried          5124
#  Wife               2331
#  Other-relative     1506
# Name: relationship, dtype: int64

# %%
data_copy['race'].unique()
# Out:
# array([' White', ' Black', ' Asian-Pac-Islander', ' Amer-Indian-Eskimo',
#        ' Other'], dtype=object)

# %%
data_copy['race'].value_counts()
# Out:
#  White                 41736
#  Black                  4683
#  Asian-Pac-Islander     1518
#  Amer-Indian-Eskimo      470
#  Other                   406
# Name: race, dtype: int64

# %%
data_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 48813 entries, 0 to 48842
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             48813 non-null  int32
#  1   workclass       48813 non-null  object
#  2   fnlwgt          48813 non-null  float64
#  3   education       48813 non-null  object
#  4   education-num   48813 non-null  float64
#  5   marital-status  48813 non-null  object
#  6   occupation      48813 non-null  object
#  7   relationship    48813 non-null  object
#  8   race            48813 non-null  object
#  9   sex             48813 non-null  object
#  10  capital-gain    48813 non-null  float64
#  11  capital-loss    48813 non-null  float64
#  12  hours-per-week  48813 non-null  float64
#  13  native-country  48813 non-null  object
#  14  class           48813 non-null  object
# dtypes: float64(5), int32(1), object(9)
# memory usage: 5.8+ MB

# %%
data_copy['sex'].unique()
# Out:
# array([' Male', ' Female'], dtype=object)

# %%
data_copy['sex'].value_counts()
# Out:
#  Male      32631
#  Female    16182
# Name: sex, dtype: int64

# %%
data_copy['capital-gain'].unique()
# Out:
# array([ 2174.,     0., 14084.,  5178.,  5013.,  2407., 14344., 15024.,
#         7688., 34095.,  4064.,  4386.,  7298.,  1409.,  3674.,  1055.,
#         3464.,  2050.,  2176.,   594., 20051.,  6849.,  4101.,  1111.,
#         8614.,  3411.,  2597., 25236.,  4650.,  9386.,  2463.,  3103.,
#        10605.,  2964.,  3325.,  2580.,  3471.,  4865., 99999.,  6514.,
#         1471.,  2329.,  2105.,  2885., 25124., 10520.,  2202.,  2961.,
#        27828.,  6767.,  2228.,  1506., 13550.,  2635.,  5556.,  4787.,
#         3781.,  3137.,  3818.,  3942.,   914.,   401.,  2829.,  2977.,
#         4934.,  2062.,  2354.,  5455., 15020.,  1424.,  3273., 22040.,
#         4416.,  3908., 10566.,   991.,  4931.,  1086.,  7430.,  6497.,
#          114.,  7896.,  2346.,  3418.,  3432.,  2907.,  1151.,  2414.,
#         2290., 15831., 41310.,  4508.,  2538.,  3456.,  6418.,  1848.,
#         3887.,  5721.,  9562.,  1455.,  2036.,  1831., 11678.,  2936.,
# ...

# %%
data_copy['capital-loss'].unique()
# Out:
# array([   0., 2042., 1408., 1902., 1573., 1887., 1719., 1762., 1564.,
#        2179., 1816., 1980., 1977., 1876., 1340., 2206., 1741., 1485.,
#        2339., 2415., 1380., 1721., 2051., 2377., 1669., 2352., 1672.,
#         653., 2392., 1504., 2001., 1590., 1651., 1628., 1848., 1740.,
#        2002., 1579., 2258., 1602.,  419., 2547., 2174., 2205., 1726.,
#        2444., 1138., 2238.,  625.,  213., 1539.,  880., 1668., 1092.,
#        1594., 3004., 2231., 1844.,  810., 2824., 2559., 2057., 1974.,
#         974., 2149., 1825., 1735., 1258., 2129., 2603., 2282.,  323.,
#        4356., 2246., 1617., 1648., 2489., 3770., 1755., 3683., 2267.,
#        2080., 2457.,  155., 3900., 2201., 1944., 2467., 2163., 2754.,
#        2472., 1411., 1429., 3175., 1510., 1870., 1911., 2465., 1421.])

# %%
data_copy['hours-per-week'].unique()
# Out:
# array([40., 13., 16., 45., 50., 80., 30., 35., 60., 20., 52., 44., 15.,
#        25., 38., 43., 55., 48., 58., 32., 70.,  2., 22., 56., 41., 28.,
#        36., 24., 46., 42., 12., 65.,  1., 10., 34., 75., 98., 33., 54.,
#         8.,  6., 64., 19., 18., 72.,  5.,  9., 47., 37., 21., 26., 14.,
#         4., 59.,  7., 99., 53., 39., 62., 57., 78., 90., 66., 11., 49.,
#        84.,  3., 17., 68., 27., 85., 31., 51., 77., 63., 23., 87., 88.,
#        73., 89., 97., 94., 29., 96., 67., 82., 86., 91., 81., 76., 92.,
#        61., 74., 95., 79., 69.])

# %%
data_copy['native-country'].unique()
# Out:
# array([' United-States', ' Cuba', ' Jamaica', ' India', ' ?', ' Mexico',
#        ' South', ' Puerto-Rico', ' Honduras', ' England', ' Canada',
#        ' Germany', ' Iran', ' Philippines', ' Italy', ' Poland',
#        ' Columbia', ' Cambodia', ' Thailand', ' Ecuador', ' Laos',
#        ' Taiwan', ' Haiti', ' Portugal', ' Dominican-Republic',
#        ' El-Salvador', ' France', ' Guatemala', ' China', ' Japan',
#        ' Yugoslavia', ' Peru', ' Outlying-US(Guam-USVI-etc)', ' Scotland',
#        ' Trinadad&Tobago', ' Greece', ' Nicaragua', ' Vietnam', ' Hong',
#        ' Ireland', ' Hungary', ' Holand-Netherlands'], dtype=object)

# %%
data_copy['native-country'].value_counts()
# Out:
#  United-States                 43810
#  Mexico                          947
#  ?                               856
#  Philippines                     295
#  Germany                         206
#  Puerto-Rico                     184
#  Canada                          182
#  El-Salvador                     155
#  India                           151
#  Cuba                            138
#  England                         127
#  China                           122
#  South                           115
#  Jamaica                         106
#  Italy                           105
#  Dominican-Republic              103
#  Japan                            92
#  Poland                           87
#  Guatemala                        86
#  Vietnam                          86
#  Columbia                         85
#  Haiti                            75
#  Portugal                         67
#  Taiwan                           65
#  Iran                             59
# ...

# %%
data_copy['native-country'] = data_copy['native-country'].str.replace('?','United-States')
# Out:
# C:\Users\adity\AppData\Local\Temp\ipykernel_2856\2200673622.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   data_copy['native-country'] = data_copy['native-country'].str.replace('?','United-States')

# %%
data_copy['native-country'].unique()
# Out:
# array([' United-States', ' Cuba', ' Jamaica', ' India', ' Mexico',
#        ' South', ' Puerto-Rico', ' Honduras', ' England', ' Canada',
#        ' Germany', ' Iran', ' Philippines', ' Italy', ' Poland',
#        ' Columbia', ' Cambodia', ' Thailand', ' Ecuador', ' Laos',
#        ' Taiwan', ' Haiti', ' Portugal', ' Dominican-Republic',
#        ' El-Salvador', ' France', ' Guatemala', ' China', ' Japan',
#        ' Yugoslavia', ' Peru', ' Outlying-US(Guam-USVI-etc)', ' Scotland',
#        ' Trinadad&Tobago', ' Greece', ' Nicaragua', ' Vietnam', ' Hong',
#        ' Ireland', ' Hungary', ' Holand-Netherlands'], dtype=object)

# %%
data_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 48813 entries, 0 to 48842
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             48813 non-null  int32
#  1   workclass       48813 non-null  object
#  2   fnlwgt          48813 non-null  float64
#  3   education       48813 non-null  object
#  4   education-num   48813 non-null  float64
#  5   marital-status  48813 non-null  object
#  6   occupation      48813 non-null  object
#  7   relationship    48813 non-null  object
#  8   race            48813 non-null  object
#  9   sex             48813 non-null  object
#  10  capital-gain    48813 non-null  float64
#  11  capital-loss    48813 non-null  float64
#  12  hours-per-week  48813 non-null  float64
#  13  native-country  48813 non-null  object
#  14  class           48813 non-null  object
# dtypes: float64(5), int32(1), object(9)
# memory usage: 5.8+ MB

# %%
data_copy['class'].unique()
# Out:
# array([' <=50K', ' >50K', ' <=50K.', ' >50K.'], dtype=object)

# %%
data_copy['class'] = data_copy['class'].str.replace('<=50K.','<=50K')
# Out:
# C:\Users\adity\AppData\Local\Temp\ipykernel_2856\1578825031.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   data_copy['class'] = data_copy['class'].str.replace('<=50K.','<=50K')

# %%
data_copy['class'] = data_copy['class'].str.replace('>50K.','>50K')
# Out:
# C:\Users\adity\AppData\Local\Temp\ipykernel_2856\3163080894.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   data_copy['class'] = data_copy['class'].str.replace('>50K.','>50K')

# %%
data_copy['class'].unique()
# Out:
# array([' <=50K', ' >50K'], dtype=object)

# %%
data_copy['class'].value_counts()
# Out:
#  <=50K    37128
#  >50K     11685
# Name: class, dtype: int64

# %%
def whitespace_remover(dataframe):
   
    # iterating over the columns
    for i in dataframe.columns:
         
        # checking datatype of each columns
        if dataframe[i].dtype == 'object':
             
            # applying strip function on column
            dataframe[i] = dataframe[i].map(str.strip)
        else:
             
            # if condition is False then it will do nothing.
            pass
 
# applying whitespace_remover function on dataframe
whitespace_remover(data_copy)

# %%
data_copy.to_csv("data/clean_censusincome",index=False)

# %%
categorical_col = [i for i in data_copy.columns if data_copy[i].dtype == 'O']

# %%
categorical_col
# Out:
# ['workclass',
#  'education',
#  'marital-status',
#  'occupation',
#  'relationship',
#  'race',
#  'sex',
#  'native-country',
#  'class']

# %%
for i in categorical_col:
    print(data_copy[i].unique())
# Out:
# ['State-gov' 'Self-emp-not-inc' 'Private' 'Federal-gov' 'Local-gov'
#  'Self-emp-inc' 'Without-pay' 'Never-worked']
# ['Bachelors' 'HS-grad' '11th' 'Masters' '9th' 'Some-college' 'Assoc-acdm'
#  'Assoc-voc' '7th-8th' 'Doctorate' 'Prof-school' '5th-6th' '10th'
#  '1st-4th' 'Preschool' '12th']
# ['Never-married' 'Married-civ-spouse' 'Divorced' 'Married-spouse-absent'
#  'Separated' 'Married-AF-spouse' 'Widowed']
# ['Adm-clerical' 'Exec-managerial' 'Handlers-cleaners' 'Prof-specialty'
#  'Other-service' 'Sales' 'Craft-repair' 'Transport-moving'
#  'Farming-fishing' 'Machine-op-inspct' 'Tech-support' 'Protective-serv'
#  'Armed-Forces' 'Priv-house-serv']
# ['Not-in-family' 'Husband' 'Wife' 'Own-child' 'Unmarried' 'Other-relative']
# ['White' 'Black' 'Asian-Pac-Islander' 'Amer-Indian-Eskimo' 'Other']
# ['Male' 'Female']
# ['United-States' 'Cuba' 'Jamaica' 'India' 'Mexico' 'South' 'Puerto-Rico'
#  'Honduras' 'England' 'Canada' 'Germany' 'Iran' 'Philippines' 'Italy'
# ...
